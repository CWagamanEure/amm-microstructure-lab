# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
sns.set_theme(style="whitegrid", context="notebook")

# %%
pool= pd.read_parquet("../../data/engineered/swapsEngineered.parquet")

# %%
cex = pd.read_csv("../../data/raw/coinbase_candles.csv")

# %%
cex = cex.set_index("timestamp")
cex.index = pd.to_datetime(cex.index)

# %%
cex.head()
# Out:
#                               open     high      low    close       volume
# timestamp
# 2021-05-05 00:00:00+00:00  3239.61  3249.78  3230.80  3234.14  1012.786517
# 2021-05-05 00:01:00+00:00  3234.46  3235.66  3209.21  3210.48   973.980393
# 2021-05-05 00:02:00+00:00  3209.82  3222.09  3201.33  3212.59  1290.689125
# 2021-05-05 00:03:00+00:00  3212.46  3247.07  3211.18  3246.86  1693.306281
# 2021-05-05 00:04:00+00:00  3247.14  3277.03  3246.73  3266.41  1071.470210

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(cex["close"])

# %%
pool.head()
# Out:
#                      block_number  \
# block_timestamp
# 2021-05-05 01:56:23      12371376
# 2021-05-05 08:23:26      12373132
# 2021-05-05 09:50:51      12373520
# 2021-05-05 11:59:57      12374077
# 2021-05-05 12:56:56      12374320
#
#                                                                tx_hash  \
# block_timestamp
# 2021-05-05 01:56:23  ce7c3c307d820785caa12938012372fc9366a614a6aacf...
# 2021-05-05 08:23:26  9a1c51b0bffbf840948f3b6e3f3e495ba1cd3fa64854f9...
# 2021-05-05 09:50:51  c58715c62a5bf70a6ca09f0e51546d6cad76c8d4fff036...
# 2021-05-05 11:59:57  288c21b8b4fbf449b1d086a06e43b124ac2bc088c3f536...
# 2021-05-05 12:56:56  67502d8ba373287f6d301f6baa77c5a5f4c80d0753c34c...
#
#                      log_index  tx_index  \
# block_timestamp
# 2021-05-05 01:56:23         26        20
# 2021-05-05 08:23:26        192       172
# 2021-05-05 09:50:51          8        18
# 2021-05-05 11:59:57         86       102
# 2021-05-05 12:56:56        257       115
#
# ...

# %%
pool.tail()
# Out:
#                      block_number  \
# block_timestamp
# 2023-05-01 22:41:59      17169010
# 2023-05-01 22:41:59      17169010
# 2023-05-01 22:42:11      17169011
# 2023-05-01 22:42:35      17169013
# 2023-05-01 23:01:47      17169107
#
#                                                                tx_hash  \
# block_timestamp
# 2023-05-01 22:41:59  4e0831cf426b1cc31970ad8087dee634615bcb14dab822...
# 2023-05-01 22:41:59  18bc64e1b075149e72ffae143f276272a9780feb351d10...
# 2023-05-01 22:42:11  7d2949b5aaab2be54a26acdb1924d4274de1773fecdc78...
# 2023-05-01 22:42:35  8dc9cd84db2e7706b87a9cf3e852ab728098c6b2785456...
# 2023-05-01 23:01:47  f065f9757ff64b3821e9e02aa4d4778bdff44235f7a8c4...
#
#                      log_index  tx_index  \
# block_timestamp
# 2023-05-01 22:41:59        295       100
# 2023-05-01 22:41:59         96        10
# 2023-05-01 22:42:11        312       111
# 2023-05-01 22:42:35        379       131
# 2023-05-01 23:01:47        401       159
#
# ...

# %%
pool = pool.rename_axis("timestamp")

# %%
pool.index = pd.to_datetime(pool.index)

# %%
cex_r = cex.rename(columns={"close": "cex_close"})

# %%
cex_r.index = pd.to_datetime(cex_r.index)

# %%
cex_r.index.dtype
# Out:
# datetime64[ns, UTC]

# %%
pool.index = pool.index.tz_localize("UTC")

# %%
pool_s = pool.sort_index()
cex_s = cex_r.sort_index()

df = pd.merge_asof(
    pool_s.reset_index().sort_values("timestamp"),
    cex_s.reset_index().sort_values("timestamp"),
    on="timestamp",
    direction="backward",         
    tolerance=pd.Timedelta("1min"),    
)

df = df.set_index("timestamp")

# %%
df.head()
# Out:
#                            block_number  \
# timestamp
# 2021-05-05 01:56:23+00:00      12371376
# 2021-05-05 08:23:26+00:00      12373132
# 2021-05-05 09:50:51+00:00      12373520
# 2021-05-05 11:59:57+00:00      12374077
# 2021-05-05 12:56:56+00:00      12374320
#
#                                                                      tx_hash  \
# timestamp
# 2021-05-05 01:56:23+00:00  ce7c3c307d820785caa12938012372fc9366a614a6aacf...
# 2021-05-05 08:23:26+00:00  9a1c51b0bffbf840948f3b6e3f3e495ba1cd3fa64854f9...
# 2021-05-05 09:50:51+00:00  c58715c62a5bf70a6ca09f0e51546d6cad76c8d4fff036...
# 2021-05-05 11:59:57+00:00  288c21b8b4fbf449b1d086a06e43b124ac2bc088c3f536...
# 2021-05-05 12:56:56+00:00  67502d8ba373287f6d301f6baa77c5a5f4c80d0753c34c...
#
#                            log_index  tx_index  \
# timestamp
# 2021-05-05 01:56:23+00:00         26        20
# 2021-05-05 08:23:26+00:00        192       172
# 2021-05-05 09:50:51+00:00          8        18
# ...

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(df["cex_close"])
ax.plot(df["price_usdc_per_weth"])

# %% [markdown]
# ## Now to compute Trade-Based LVR

# %%
df["amount1"].dtype
# Out:
# string[python]

# %%
df["amount1"] = df["amount1"].astype(float)

# %%
df["amount1"].dtype
# Out:
# dtype('float64')

# %%
df["q_weth"] = -df["amount1"]

# %%
df.head()
# Out:
#                            block_number  \
# timestamp
# 2021-05-05 01:56:23+00:00      12371376
# 2021-05-05 08:23:26+00:00      12373132
# 2021-05-05 09:50:51+00:00      12373520
# 2021-05-05 11:59:57+00:00      12374077
# 2021-05-05 12:56:56+00:00      12374320
#
#                                                                      tx_hash  \
# timestamp
# 2021-05-05 01:56:23+00:00  ce7c3c307d820785caa12938012372fc9366a614a6aacf...
# 2021-05-05 08:23:26+00:00  9a1c51b0bffbf840948f3b6e3f3e495ba1cd3fa64854f9...
# 2021-05-05 09:50:51+00:00  c58715c62a5bf70a6ca09f0e51546d6cad76c8d4fff036...
# 2021-05-05 11:59:57+00:00  288c21b8b4fbf449b1d086a06e43b124ac2bc088c3f536...
# 2021-05-05 12:56:56+00:00  67502d8ba373287f6d301f6baa77c5a5f4c80d0753c34c...
#
#                            log_index  tx_index  \
# timestamp
# 2021-05-05 01:56:23+00:00         26        20
# 2021-05-05 08:23:26+00:00        192       172
# 2021-05-05 09:50:51+00:00          8        18
# ...

# %%
df["p_pool"] = df["price_usdc_per_weth"]
df["p_cex"] = df["cex_close"]

# %%
def lvr_row(row):
    '''
    per swap lvr computed for each side
    '''
    q = row["q_weth"]
    p_pool = row["p_pool"]
    p_cex = row["p_cex"]

    if q > 0:
        edge = p_cex - p_pool
        return max(edge, 0.0) * q
    elif q < 0:
        q_abs = -q
        edge = p_pool - p_cex
        return max(edge, 0.0) * q_abs
    else:
        return 0.0

# %%
df["dLVR"] = df.apply(lvr_row, axis=1)
df["LVR_cum"] = df["dLVR"].cumsum()

# %%
df[["q_weth","p_pool","p_cex","dLVR","LVR_cum"]].head()
# Out:
#                                  q_weth       p_pool    p_cex          dLVR  \
# timestamp
# 2021-05-05 01:56:23+00:00 -1.000000e+14  3306.001763  3367.93  0.000000e+00
# 2021-05-05 08:23:26+00:00 -5.000000e+16  3301.602222  3346.97  0.000000e+00
# 2021-05-05 09:50:51+00:00 -1.000000e+14  3301.593431  3369.56  0.000000e+00
# 2021-05-05 11:59:57+00:00  3.291690e+05  3301.593431  3354.78  1.750737e+07
# 2021-05-05 12:56:56+00:00  4.678809e+17  3343.219561  3378.66  1.658190e+19
#
#                                 LVR_cum
# timestamp
# 2021-05-05 01:56:23+00:00  0.000000e+00
# 2021-05-05 08:23:26+00:00  0.000000e+00
# 2021-05-05 09:50:51+00:00  0.000000e+00
# 2021-05-05 11:59:57+00:00  1.750737e+07
# 2021-05-05 12:56:56+00:00  1.658190e+19

# %%
fig, ax = plt.subplots(figsize=(10,4))
df["LVR_cum"].plot(ax=ax)
ax.set_title("Cumulative LVR (unscaled units)")
ax.set_ylabel("LVR")
# Out:
# Text(0, 0.5, 'LVR')

# %%
fig, ax = plt.subplots(figsize=(10,4))
df["dLVR"].plot(ax=ax)
ax.set_title("LVR Overtime")
ax.set_ylabel("LVR")
# Out:
# Text(0, 0.5, 'LVR')

# %%
DEC_WETH = 18  # convert to WETH maybe instead of wei
df["q_weth_eth"] = df["q_weth"] / 10**DEC_WETH

df["dLVR_usd"] = df.apply(
    lambda row: max(row["p_cex"] - row["p_pool"], 0) * row["q_weth_eth"]
                if row["q_weth_eth"] > 0 else
                max(row["p_pool"] - row["p_cex"], 0) * -row["q_weth_eth"],
    axis=1
)
df["LVR_cum_usd"] = df["dLVR_usd"].cumsum()

# %%
fig, ax = plt.subplots(figsize=(10,4))
df["LVR_cum_usd"].plot(ax=ax)
ax.set_title("Cumulative LVR (in USD)")
ax.set_ylabel("LVR")
# Out:
# Text(0, 0.5, 'LVR')

# %%
fig, ax = plt.subplots(figsize=(10,4))
df["dLVR_usd"].plot(ax=ax)
ax.set_title("LVR Overtime USD")
ax.set_ylabel("LVR (USD)")
# Out:
# Text(0, 0.5, 'LVR (USD)')

# %%
# Timeseries lvr
lvr_hourly = df["dLVR"].resample("1H").sum()
lvr_daily  = df["dLVR"].resample("1D").sum()
# Out:
# /var/folders/3t/0nrchrfd79xcg6j3q6yk110m0000gn/T/ipykernel_26532/3865611709.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   lvr_hourly = df["dLVR"].resample("1H").sum()

# %% [markdown]
# ## Now the fun begins: Lets start some basic forecasting and correlation stuff

# %%
# Got that hourly lvr
lvr_1h = df["dLVR_usd"].resample("1H").sum()
# Out:
# /var/folders/3t/0nrchrfd79xcg6j3q6yk110m0000gn/T/ipykernel_26532/4276811180.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   lvr_1h = df["dLVR_usd"].resample("1H").sum()

# %%
px = df["cex_close"]
returns = np.log(px).diff().dropna()
rv_5m = (returns**2).resample("5T").sum()
rv_1h = rv_5m.resample("1H").sum()
# Out:
# /var/folders/3t/0nrchrfd79xcg6j3q6yk110m0000gn/T/ipykernel_26532/3302562576.py:3: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rv_5m = (returns**2).resample("5T").sum()
# /var/folders/3t/0nrchrfd79xcg6j3q6yk110m0000gn/T/ipykernel_26532/3302562576.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   rv_1h = rv_5m.resample("1H").sum()

# %% [markdown]
# ### Simple OLS of 1hr LVR given features:
# 1. CEX Hourly returns
# 2. Basis
# 3. liquidity of pool

# %%
features = ["RV_1h", "basis_abs", "liq"]

# %%
from sklearn.preprocessing import StandardScaler

cols = ["RV_1h", "basis_abs", "liq"]
X_raw = data[cols].values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_raw)

X = sm.add_constant(X_scaled)
y = data["y"]

print("matrix rank after scaling:", np.linalg.matrix_rank(X))
# Out:
# matrix rank after scaling: 4

# %%
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.154
# Model:                            OLS   Adj. R-squared:                  0.154
# Method:                 Least Squares   F-statistic:                     1043.
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):               0.00
# Time:                        11:22:24   Log-Likelihood:                -38703.
# No. Observations:               17200   AIC:                         7.741e+04
# Df Residuals:                   17196   BIC:                         7.744e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.9232      0.018    452.501      0.000       7.889       7.958
# ...
