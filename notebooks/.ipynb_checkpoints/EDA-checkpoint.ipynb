# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet("../data/processed/decoded_pool_transactions.parquet")

# %% [markdown]
# ## Split into each individual transaction type

# %%
d = df
swaps = (
    d[d["event"] == "Swap"]
    .copy()
    [[
        "block_timestamp", "block_number", "tx_hash", "log_index", "tx_index",
        "sender", "recipient",
        "amount0", "amount1",
        "sqrtPriceX96", "liquidity", "tick"
    ]]
)
mints = (
    d[d["event"] == "Mint"]
    .copy()
    [[
        "block_timestamp", "block_number", "tx_hash", "log_index", "tx_index",
        "sender", "owner",
        "tickLower", "tickUpper",
        "amount", "amount0", "amount1"
    ]]
)

burns = (
    d[d["event"] == "Burn"]
    .copy()
    [[
        "block_timestamp", "block_number", "tx_hash", "log_index", "tx_index",
        "owner",
        "tickLower", "tickUpper",
        "amount", "amount0", "amount1"
    ]]
)

collects = (
    d[d["event"] == "Collect"]
    .copy()
    [[
        "block_timestamp", "block_number", "tx_hash", "log_index", "tx_index",
        "recipient", "owner",
        "tickLower", "tickUpper",
        "amount0", "amount1"
    ]]
)

# %%
swaps.head()
# Out:
#        block_timestamp  block_number  \
# 0  2022-11-16 21:34:59      15985296
# 10 2022-11-16 21:43:23      15985338
# 11 2022-11-16 21:44:11      15985342
# 14 2022-11-16 21:45:23      15985348
# 15 2022-11-16 21:45:35      15985349
#
#                                               tx_hash  log_index  tx_index  \
# 0   313f88a08cbda72eca653433f60d35ac6044597fe03cae...        327       150
# 10  1cf0bdee0932b166e7bc5c0b63a8ff79f9e0c14a9a5627...        178       125
# 11  0dab5f347d405ccb58406816534274f09f3a92714bee0c...         12         2
# 14  7b149365d91334462a8f45432060c8009b58d189c2c3d9...        252       165
# 15  971118fea7a5cb02e7304a7094043282deab2c526dcaa2...        238       118
#
#                                         sender  \
# 0   0xE592427A0AEce92De3Edee1F18E0157C05861564
# 10  0x68b3465833fb72A70ecDF485E0e4C7bD8665Fc45
# 11  0x0087BB802D9C0e343F00510000729031ce00bf27
# 14  0x68b3465833fb72A70ecDF485E0e4C7bD8665Fc45
# ...

# %% [markdown]
# ## Save each

# %%
swaps.to_parquet("../data/processed/usdcweth_swaps.parquet", index=False)
mints.to_parquet("../data/processed/usdcweth_mints.parquet", index=False)
burns.to_parquet("../data/processed/usdcweth_burns.parquet", index=False)
collects.to_parquet("../data/processed/usdcweth_collects.parquet", index=False)

# %%
USDC_DEC = 6
WETH_DEC = 18
Q192 = 2 ** 192

sw = swaps.sort_values("block_timestamp").copy()
sqrtP = swaps["sqrtPriceX96"].astype(float)
sw["price_weth_per_usdc"] = (sqrtP**2 / Q192)*(10 ** (USDC_DEC - WETH_DEC))
sw["price_usdc_per_weth"] = 1/sw["price_weth_per_usdc"]

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(sw["block_timestamp"], sw["price_usdc_per_weth"].astype(float))
ax.set_xlabel("Time")
ax.set_ylabel("USDC per WETH")
ax.set_title("USDC/WETH Mid Price from Pool Over Time")
# Out:
# Text(0.5, 1.0, 'USDC/WETH Mid Price from Pool Over Time')

# %%
fig.savefig("../figures/USDC-WETH_Mid_Price_from_Pool_Over_Time.png", dpi=300, bbox_inches="tight")
